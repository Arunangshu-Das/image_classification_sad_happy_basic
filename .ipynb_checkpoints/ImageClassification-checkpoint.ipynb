# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (2.8.0)
# Requirement already satisfied: tensorflow-gpu in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (2.5.0)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (3.4.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: setuptools in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (56.0.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.24.0)
# Collecting numpy>=1.20
#   Using cached numpy-1.23.3-cp39-cp39-win_amd64.whl (14.7 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-gpu) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-gpu) (2.5.0.dev2021032900)
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.10.0-cp39-cp39-win_amd64.whl (455.9 MB)
#      -------------------------------------- 455.9/455.9 MB 2.2 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      -------------------------------------- 438.7/438.7 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-gpu) (21.0)
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.2-cp39-cp39-win_amd64.whl (444.1 MB)
#      -------------------------------------- 444.1/444.1 MB 1.5 MB/s eta 0:00:00
# Collecting absl-py>=0.4.0
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
#      -------------------------------------- 444.0/444.0 MB 1.9 MB/s eta 0:00:00
#   Downloading tensorflow_gpu-2.9.0-cp39-cp39-win_amd64.whl (444.0 MB)
#      -------------------------------------- 444.0/444.0 MB 1.4 MB/s eta 0:00:00
#   Downloading tensorflow_gpu-2.8.3-cp39-cp39-win_amd64.whl (438.4 MB)
#      -------------------------------------- 438.4/438.4 MB 1.7 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      -------------------------------------- 462.3/462.3 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.32.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.5.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.1.1)
# Installing collected packages: tensorflow-estimator, numpy, tensorflow-gpu
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
#   Attempting uninstall: tensorflow-gpu
#     Found existing installation: tensorflow-gpu 2.5.0
#     Uninstalling tensorflow-gpu-2.5.0:
#       Successfully uninstalled tensorflow-gpu-2.5.0
# Successfully installed numpy-1.23.3 tensorflow-estimator-2.8.0 tensorflow-gpu-2.8.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.3 which is incompatible.
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
os.path.join('data','happy')
# Out:
# 'data\\happy'

# %%
os.listdir('data')
# Out:
# ['happy', 'sad']

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.13.0
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anyio                         3.6.1
# argon2-cffi                   20.1.0
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         21.2.0
# Babel                         2.9.1
# backcall                      0.2.0
# bcrypt                        4.0.0
# bleach                        4.1.0
# cachetools                    4.2.2
# certifi                       2021.5.30
# cffi                          1.14.6
# chardet                       4.0.0
# charset-normalizer            2.1.1
# click                         8.1.3
# cloudpickle                   2.2.0
# cmake                         3.24.1.1
# colorama                      0.4.4
# cryptography                  38.0.1
# cycler                        0.10.0
# dataframe                     0.2.1.3
# debugpy                       1.4.1
# decorator                     5.0.9
# defusedxml                    0.7.1
# docutils                      0.17.1
# easyocr                       1.6.2
# entrypoints                   0.3
# et-xmlfile                    1.1.0
# fastapi                       0.85.0
# ffmpy                         0.3.0
# filelock                      3.8.0
# Flask                         2.2.2
# flatbuffers                   1.12
# frozenlist                    1.3.1
# fsspec                        2022.8.2
# gast                          0.4.0
# google-auth                   1.32.0
# google-auth-oauthlib          0.4.4
# google-pasta                  0.2.0
# gradio                        3.4.1
# grpcio                        1.34.1
# gym                           0.26.2
# gym-notices                   0.0.8
# h11                           0.12.0
# h5py                          3.1.0
# httpcore                      0.15.0
# httpx                         0.23.0
# huggingface-hub               0.10.0
# ibm-cloud-sdk-core            3.16.0
# ibm-watson                    6.1.0
# idna                          2.10
# imageio                       2.22.1
# imagesize                     1.2.0
# importlib-metadata            4.12.0
# imutils                       0.5.4
# iniconfig                     1.1.1
# ipykernel                     6.2.0
# ipython                       7.26.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.2
# itsdangerous                  2.1.2
# jedi                          0.18.0
# Jinja2                        3.0.1
# joblib                        1.0.1
# jsonschema                    3.2.0
# jupyter                       1.0.0
# jupyter-client                7.0.1
# jupyter-console               6.4.0
# jupyter-core                  4.7.1
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            3.0.3
# keras                         2.8.0
# keras-nightly                 2.5.0.dev2021032900
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.1
# libclang                      13.0.0
# linkify-it-py                 1.0.3
# Markdown                      3.3.4
# markdown-it-py                2.1.0
# MarkupSafe                    2.1.1
# matplotlib                    3.4.3
# matplotlib-inline             0.1.2
# mdit-py-plugins               0.3.1
# mdurl                         0.1.2
# mediapipe                     0.8.11
# mistune                       0.8.4
# multidict                     6.0.2
# mysql-connector-python        8.0.30
# mysqlclient                   2.1.1
# nbclient                      0.5.4
# nbconvert                     6.1.0
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# networkx                      2.8.7
# ninja                         1.10.2.4
# nose                          1.3.7
# notebook                      6.4.10
# numpy                         1.23.3
# oauthlib                      3.1.1
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.5.4.60
# openpyxl                      3.0.7
# opt-einsum                    3.3.0
# orjson                        3.8.0
# packaging                     21.0
# pandas                        1.3.2
# pandocfilters                 1.4.3
# paramiko                      2.11.0
# parso                         0.8.2
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.0.4
# pluggy                        0.13.1
# prometheus-client             0.11.0
# prompt-toolkit                3.0.20
# protobuf                      3.17.3
# py                            1.10.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pyclipper                     1.3.0.post3
# pycparser                     2.20
# pycryptodome                  3.15.0
# pydantic                      1.10.2
# pydub                         0.25.1
# pyglet                        1.5.27
# Pygments                      2.10.0
# PyJWT                         2.5.0
# pymongo                       4.1.1
# PyNaCl                        1.5.0
# pyparsing                     2.4.7
# pyrsistent                    0.18.0
# pytest                        6.2.4
# python-bidi                   0.4.2
# python-dateutil               2.8.2
# python-multipart              0.0.5
# pytz                          2021.1
# PyWavelets                    1.4.1
# pywin32                       301
# pywinpty                      1.1.3
# PyYAML                        6.0
# pyzmq                         22.2.1
# qtconsole                     5.1.1
# QtPy                          1.10.0
# regex                         2022.9.13
# requests                      2.28.1
# requests-oauthlib             1.3.0
# rfc3986                       1.5.0
# rsa                           4.7.2
# scikit-image                  0.19.3
# scikit-learn                  1.0.2
# scipy                         1.7.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    56.0.0
# Shapely                       1.8.4
# six                           1.15.0
# sniffio                       1.3.0
# snowballstemmer               2.1.0
# Sphinx                        4.1.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# starlette                     0.20.4
# tabulate                      0.8.9
# tensorboard                   2.8.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow                    2.8.0
# tensorflow-estimator          2.8.0
# tensorflow-gpu                2.8.3
# tensorflow-io-gcs-filesystem  0.24.0
# termcolor                     1.1.0
# terminado                     0.11.1
# testpath                      0.5.0
# tf-estimator-nightly          2.8.0.dev2021122109
# threadpoolctl                 2.2.0
# tifffile                      2022.8.12
# tokenizers                    0.12.1
# toml                          0.10.2
# torch                         1.8.2+cu111
# torchaudio                    0.8.2
# torchvision                   0.9.2+cu111
# tornado                       6.1
# tqdm                          4.64.1
# traitlets                     5.0.5
# transformers                  4.22.2
# typing_extensions             4.4.0
# uc-micro-py                   1.0.1
# urllib3                       1.26.6
# uvicorn                       0.18.3
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.1.0
# websockets                    10.3
# Werkzeug                      2.2.2
# wheel                         0.36.2
# widgetsnbextension            4.0.3
# wrapt                         1.12.1
# xlrd                          2.0.1
# yarl                          1.8.1
# youtube-dl                    2021.12.17
# zipp                          3.8.1
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\users\user\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
import imghdr

# %%
data_dir='data'
image_exts=['jpg','jpeg','bmp','png']

# %%
os.listdir(os.path.join(data_dir,'happy'))
# Out:
# ['05-12-21-happy-people.jpg',
#  '07-120104-happy_people_are_not_nice_people.jpg',
#  '1-2.jpg',
#  '1000_F_42220133_toAU6USGY9jVr2XJFLssfG00cSYIJ173.jpg',
#  '11-Habits-of-Truly-Happy-People.jpg',
#  '154006829.jpg',
#  '170404-happy-workers-feature.jpg',
#  '1902539.jpg',
#  '1902540.jpg',
#  '1902587.jpg',
#  '1920px-face-smile.svg_.png.jpg',
#  '1HEoLBLidT2u4mhJ0oiDgig.png',
#  '227-2271622_happy-people-business-team-celebrating-png.png',
#  '60632274._UY200_.jpg',
#  '7-Habits-of-Happy-People-image.jpeg',
#  '7-principles-of-successful-and-happy-people.png',
#  '7Y57w0983emdERAoQylUHIGkoEk1cIFvPkXDbeA2lVA.jpg',
#  '8cxKy5g9i.jpg',
#  '960x0.jpg',
#  'ADea4I4CgV4-hlxUOAdFjyNYonWRHO6Pu4jWXKk9BJScXws64-c-mo.jpg',
#  'A_Sep20_14_1189155141.jpg',
#  'GettyImages-565706549-949x534.jpg',
#  'GettyImages-871518740-1024x707.jpg',
#  'HAPPY-PEOPLE-CLUB-LOGO.jpg',
#  'Happiness-Habits-10-Things-Happy-People-Do-Before-Bed.jpg',
#  'Happy-people-800x533.jpg',
#  'Happy-people-raise-happy-kids-raise-yourself-first.jpg',
#  'HappyPeopleBanner.png',
#  'Happy_People_Happy_Man.jpg',
#  'How-to-Be-Happy_1200x628-facebook.jpg',
#  'How_Happy_Are_People_at_Work.jpg',
#  'MV5BMTM3ODM0NTQ1MF5BMl5BanBnXkFtZTcwMzAxMTM5OA._V1_.jpg',
#  'Screen-Shot-2012-10-23-at-12.57.22-PM.png',
#  'THPC_Logo-jpeg.jpg',
#  'Top-Secrets-of-How-to-be-Happy.jpg',
#  'Travis-Bradberry-Happy.jpg',
#  '_happy_jumping_on_beach-40815.jpg',
#  'bigstock-Portrait-Of-Smiling-Employees-272904928-min-scaled.jpg',
#  'blog_image_20180219221810890.jpg',
#  'brady-bunch-3.jpg',
#  'e162ccda8ce0f197f8863f327add9233.jpg',
#  'fiendship-concept-smiling-friends-communication-weekend-university-123724503.jpg',
#  'friends-happy-190821-800x450.jpg',
#  'getty_152414899_97046097045006_68075.jpg',
#  'getty_478389113_970647970450091_99776.jpg',
#  'getty_494581822_130796.jpg',
#  'getty_505175324_2000131020009280246_158016.jpg',
#  'goup-happy-people-group-jumping-isolated-white-background-35582232.jpg',
#  'group-of-happy-people-2.jpg',
#  'habits-of-happy-people-cr3.jpg',
#  'habits-of-happy-people.jpg',
#  'habits-that-define-very-happy-people.jpg',
#  'happiness.jpg',
#  'happinessa.jpg',
#  'happy-girl-in-leaves.jpg',
#  'happy-people-1024x768.jpeg',
#  'happy-people-13772392.jpg',
#  'happy-people-14410042.jpg',
#  'happy-people-702x336.jpg',
#  'happy-people-black-and-white-720x360.jpg',
#  'happy-people-group-fb.jpg',
#  'happy-people-vector-29209040.jpg',
#  'happy-people-vector-839522.jpg',
#  'happy-people.jpg',
#  'happy-people21.jpg',
#  'happy-people_1463241208.jpg',
#  'happy-person.jpeg',
#  'happy-woman-in-nature-at-sunset.jpg',
#  'happypeople-1024x679.jpg',
#  'hdptcar-fi-2.jpg',
#  'how-happy-are-healthy-people.jpg',
#  'hqdefault.jpg',
#  'iStock-1212931050.jpg',
#  'image.jpeg',
#  'image10.jpeg',
#  'image11.jpeg',
#  'image12.jpeg',
#  'image13.jpeg',
#  'image14.jpeg',
#  'image15.jpeg',
#  'image16.jpeg',
#  'image17.jpeg',
#  'image18.jpeg',
#  'image19.jpeg',
#  'image2.jpeg',
#  'image20.jpeg',
#  'image21.jpeg',
#  'image22.jpeg',
#  'image23.jpeg',
#  'image24.jpeg',
#  'image25.jpeg',
#  'image26.jpeg',
#  'image27.jpeg',
#  'image28.jpeg',
#  'image29.jpeg',
#  'image3.jpeg',
#  'image30.jpeg',
#  'image31.jpeg',
#  'image32.png',
#  'image4.jpeg',
#  'image5.jpeg',
#  'image6.jpeg',
#  'image7.jpeg',
#  'image8.jpeg',
#  'image9.jpeg',
#  'images.jpg',
#  'images10.jpg',
#  'images11.jpg',
#  'images12.jpg',
#  'images13.jpg',
#  'images14.jpg',
#  'images15.jpg',
#  'images16.jpg',
#  'images17.jpg',
#  'images18.jpg',
#  'images19.jpg',
#  'images2.jpg',
#  'images20.jpg',
#  'images21.jpg',
#  'images22.jpg',
#  'images23.jpg',
#  'images24.jpg',
#  'images25.jpg',
#  'images26.jpg',
#  'images27.jpg',
#  'images28.jpg',
#  'images29.jpg',
#  'images3.jpg',
#  'images30.jpg',
#  'images31.jpg',
#  'images32.jpg',
#  'images33.jpg',
#  'images34.jpg',
#  'images35.jpg',
#  'images36.jpg',
#  'images4.jpg',
#  'images5.jpg',
#  'images6.jpg',
#  'images7.jpg',
#  'images8.jpg',
#  'images9.jpg',
#  'jumping_for_joy_for_3_kinds_of_happy_people.jpg',
#  'maxresdefault.jpg',
#  'maxresdefault2.jpg',
#  'o-HAPPY-facebook.jpg',
#  'physed-happiness-facebookJumbo.jpg',
#  'smile.woman_.jpg',
#  'the-habits-of-happy-people-a-meditation-day-course-611337.jpg',
#  'tmp_6mv7xy_5d5b15258a507669_GettyImages-847741712.jpg',
#  'traitshappypeople.jpg',
#  'web3-happy-people-outside-smile-sun-nature-eduardo-dutra-620857-unsplash.jpg',
#  'what-makes-people-happy.jpeg',
#  'young-and-happy-people-vector-15114154.jpg']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
# Out:
# Image not in ext list data\angry\60552212-angry-people-illustration-design-collection.jpg
# Image not in ext list data\angry\v4-460px-Communicate-With-an-Angry-Person-Step-1-Version-3.jpg.webp
# Image not in ext list data\angry\5cd88fd324000032007de6c0.jpeg
# Image not in ext list data\angry\angry-man-260nw-670660900.jpg
# Image not in ext list data\angry\angry-people-screaming-260nw-292800785.jpg
# Image not in ext list data\angry\young-hispanic-woman-wearing-casual-260nw-1937876830.jpg
# Image not in ext list data\angry\woman-rage-very-angry-dissatisfied-260nw-524205757.jpg
# Image not in ext list data\angry\depositphotos_52761619-stock-photo-angry-young-woman-blowing-steam.jpg
# Image not in ext list data\angry\upset-unshaven-person-260nw-1021044943.jpg
# Image not in ext list data\angry\v4-460px-Communicate-With-an-Angry-Person-Step-3-Version-3.jpg.webp
# Image not in ext list data\angry\0I7epAOu2NsJNIP_C.jpg
# Image not in ext list data\angry\1VXusK7iyZS1hntiEdmBQ2w.jpeg
# Image not in ext list data\angry\angry-complaining-group-business-people-260nw-1921199924.jpg

# %% [markdown]
# Load data

# %%
data=tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 404 files belonging to 3 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator=data.as_numpy_iterator()

# %%
data_iterator

# %%
batch=data_iterator.next()

# %%
batch
# Out:
# (array([[[[2.41017578e+02, 2.41017578e+02, 2.41017578e+02],
#           [2.42000000e+02, 2.42000000e+02, 2.42000000e+02],
#           [2.42087891e+02, 2.42087891e+02, 2.42087891e+02],
#           ...,
#           [3.04726562e+01, 3.14726562e+01, 2.34726562e+01],
#           [3.66835938e+01, 3.76835938e+01, 2.96835938e+01],
#           [3.40527344e+01, 3.50527344e+01, 2.70527344e+01]],
#
#          [[2.41017578e+02, 2.41017578e+02, 2.41017578e+02],
#           [2.42000000e+02, 2.42000000e+02, 2.42000000e+02],
#           [2.42087891e+02, 2.42087891e+02, 2.42087891e+02],
#           ...,
#           [3.05265579e+01, 3.15265579e+01, 2.35265579e+01],
#           [3.66835938e+01, 3.76835938e+01, 2.96835938e+01],
#           [3.52577362e+01, 3.62577362e+01, 2.82577362e+01]],
#
#          [[2.41366791e+02, 2.41366791e+02, 2.41366791e+02],
#           [2.42018738e+02, 2.42018738e+02, 2.42018738e+02],
#           [2.42443359e+02, 2.42443359e+02, 2.42443359e+02],
#           ...,
#           [3.05605469e+01, 3.15605469e+01, 2.42714844e+01],
#           [3.66835938e+01, 3.76835938e+01, 3.03945312e+01],
#           [3.67160187e+01, 3.77160187e+01, 3.04269562e+01]],
#
#          ...,
#
#          [[1.15425781e+02, 1.15425781e+02, 1.15425781e+02],
#           [2.51158203e+02, 2.51158203e+02, 2.51158203e+02],
#           [2.54087891e+02, 2.54087891e+02, 2.54087891e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]],
#
#          [[1.15425781e+02, 1.15425781e+02, 1.15425781e+02],
#           [2.51158203e+02, 2.51158203e+02, 2.51158203e+02],
#           [2.54087891e+02, 2.54087891e+02, 2.54087891e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]],
#
#          [[1.15425781e+02, 1.15425781e+02, 1.15425781e+02],
#           [2.51158203e+02, 2.51158203e+02, 2.51158203e+02],
#           [2.54087891e+02, 2.54087891e+02, 2.54087891e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]]],
#
#
#         [[[0.00000000e+00, 1.25000000e+02, 2.16000000e+02],
#           [0.00000000e+00, 1.25111328e+02, 2.16111328e+02],
#           [0.00000000e+00, 1.26000000e+02, 2.17000000e+02],
#           ...,
#           [0.00000000e+00, 1.24000000e+02, 2.14000000e+02],
#           [0.00000000e+00, 1.24888672e+02, 2.12222656e+02],
#           [0.00000000e+00, 1.25000000e+02, 2.12000000e+02]],
#
#          [[0.00000000e+00, 1.25000000e+02, 2.16000000e+02],
#           [0.00000000e+00, 1.25111328e+02, 2.16111328e+02],
#           [0.00000000e+00, 1.26000000e+02, 2.17000000e+02],
#           ...,
#           [0.00000000e+00, 1.24000000e+02, 2.14212372e+02],
#           [0.00000000e+00, 1.24888672e+02, 2.12222656e+02],
#           [0.00000000e+00, 1.25000000e+02, 2.12000000e+02]],
#
#          [[0.00000000e+00, 1.25287109e+02, 2.16287109e+02],
#           [0.00000000e+00, 1.25366470e+02, 2.16366470e+02],
#           [0.00000000e+00, 1.26053268e+02, 2.17053268e+02],
#           ...,
#           [0.00000000e+00, 1.24287109e+02, 2.14658203e+02],
#           [0.00000000e+00, 1.24920639e+02, 2.13020050e+02],
#           [0.00000000e+00, 1.25000000e+02, 2.12861328e+02]],
#
#          ...,
#
#          [[1.14181290e+02, 1.28829727e+02, 5.38190727e+01],
#           [1.18454178e+02, 1.35028397e+02, 5.99639435e+01],
#           [1.11505859e+02, 1.28504440e+02, 5.50317879e+01],
#           ...,
#           [8.59836960e+01, 1.05935745e+02, 4.55163612e+01],
#           [9.10815048e+01, 1.06611328e+02, 4.54355469e+01],
#           [9.66651306e+01, 1.11260651e+02, 4.99735451e+01]],
#
#          [[1.19079086e+02, 1.32297836e+02, 5.77096977e+01],
#           [1.20964661e+02, 1.36061569e+02, 6.13318443e+01],
#           [1.16937500e+02, 1.32104752e+02, 5.93469429e+01],
#           ...,
#           [8.11246643e+01, 1.00609039e+02, 3.97267494e+01],
#           [8.78293304e+01, 1.02274643e+02, 4.09106216e+01],
#           [9.24243240e+01, 1.06424324e+02, 4.49965897e+01]],
#
#          [[1.23000000e+02, 1.35074219e+02, 6.10371094e+01],
#           [1.23000000e+02, 1.36888672e+02, 6.22226562e+01],
#           [1.21515625e+02, 1.35072266e+02, 6.28867188e+01],
#           ...,
#           [7.65878906e+01, 9.60722656e+01, 3.42578125e+01],
#           [8.43320312e+01, 9.87773438e+01, 3.67773438e+01],
#           [8.78886719e+01, 1.01888672e+02, 3.98886719e+01]]],
#
#
#         [[[9.50000000e+00, 8.50000000e+00, 6.50000000e+00],
#           [6.07421875e+00, 3.57421875e+00, 4.57421875e+00],
#           [1.75000000e+00, 1.75000000e+00, 1.75000000e+00],
#           ...,
#           [1.09285156e+02, 7.83632812e+01, 5.59609375e+01],
#           [1.11617188e+02, 7.25703125e+01, 4.15078125e+01],
#           [1.13445312e+02, 7.81523438e+01, 5.07382812e+01]],
#
#          [[1.91367188e+01, 1.81367188e+01, 1.61367188e+01],
#           [4.25781250e+00, 1.75781250e+00, 2.75781250e+00],
#           [1.17187500e+00, 1.17187500e+00, 1.17187500e+00],
#           ...,
#           [6.95039062e+01, 3.79335938e+01, 1.32343750e+01],
#           [1.01710938e+02, 5.38750000e+01, 2.50117188e+01],
#           [9.16992188e+01, 5.10429688e+01, 1.94570312e+01]],
#
#          [[4.50000000e+00, 3.50000000e+00, 1.50000000e+00],
#           [2.00000000e+00, 7.03125000e-02, 1.10546875e+00],
#           [4.68750000e-02, 1.17187500e-02, 0.00000000e+00],
#           ...,
#           [9.78281250e+01, 5.56523438e+01, 3.28203125e+01],
#           [1.06226562e+02, 6.24765625e+01, 3.34062500e+01],
#           [9.57343750e+01, 5.27343750e+01, 1.78515625e+01]],
#
#          ...,
#
#          [[1.64363281e+02, 8.43164062e+01, 3.25742188e+01],
#           [1.74753906e+02, 8.77890625e+01, 4.31250000e+01],
#           [2.01699219e+02, 1.22652344e+02, 6.55273438e+01],
#           ...,
#           [2.48000000e+02, 2.47000000e+02, 2.42000000e+02],
#           [2.49000000e+02, 2.48000000e+02, 2.43000000e+02],
#           [2.48046875e+02, 2.47046875e+02, 2.42046875e+02]],
#
#          [[2.16742188e+02, 1.37535156e+02, 8.14062500e+01],
#           [1.46214844e+02, 6.32148438e+01, 3.23710938e+01],
#           [1.87921875e+02, 1.06921875e+02, 5.99218750e+01],
#           ...,
#           [2.50000000e+02, 2.47000000e+02, 2.42000000e+02],
#           [2.50000000e+02, 2.47000000e+02, 2.42000000e+02],
#           [2.49000000e+02, 2.48000000e+02, 2.43000000e+02]],
#
#          [[2.10105469e+02, 1.31105469e+02, 7.27578125e+01],
#           [1.72117188e+02, 9.26171875e+01, 5.03359375e+01],
#           [1.72144531e+02, 9.58945312e+01, 4.48945312e+01],
#           ...,
#           [2.50000000e+02, 2.47000000e+02, 2.42000000e+02],
#           [2.50000000e+02, 2.47000000e+02, 2.42000000e+02],
#           [2.49000000e+02, 2.48000000e+02, 2.43000000e+02]]],
#
#
#         ...,
#
#
#         [[[2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           ...,
#           [1.42000000e+02, 1.30476562e+02, 1.20984375e+02],
#           [1.44781250e+02, 1.34781250e+02, 1.24781250e+02],
#           [1.48695312e+02, 1.38695312e+02, 1.28695312e+02]],
#
#          [[2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           ...,
#           [1.42921875e+02, 1.31398438e+02, 1.21906250e+02],
#           [1.45703125e+02, 1.35703125e+02, 1.25703125e+02],
#           [1.49617188e+02, 1.39617188e+02, 1.29617188e+02]],
#
#          [[2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           [2.49000000e+02, 2.49000000e+02, 2.41000000e+02],
#           ...,
#           [1.44354675e+02, 1.32831238e+02, 1.23339050e+02],
#           [1.47116882e+02, 1.37116882e+02, 1.27116882e+02],
#           [1.51000000e+02, 1.41000000e+02, 1.31000000e+02]],
#
#          ...,
#
#          [[5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           ...,
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01]],
#
#          [[5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           ...,
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01]],
#
#          [[5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           [5.70000000e+01, 3.70000000e+01, 2.80000000e+01],
#           ...,
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01],
#           [6.60000000e+01, 4.60000000e+01, 3.70000000e+01]]],
#
#
#         [[[2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]],
#
#          [[2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]],
#
#          [[2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           ...,
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02],
#           [2.55000000e+02, 2.55000000e+02, 2.55000000e+02]],
#
#          ...,
#
#          [[2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.46000000e+02, 2.37000000e+02, 2.30000000e+02],
#           ...,
#           [2.14195068e+02, 1.46559937e+02, 1.05807861e+02],
#           [2.08536011e+02, 1.25593506e+02, 7.66955566e+01],
#           [1.95827515e+02, 1.39226318e+02, 1.02907104e+02]],
#
#          [[2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.46000000e+02, 2.37000000e+02, 2.30000000e+02],
#           ...,
#           [2.18054688e+02, 1.49516724e+02, 1.12984375e+02],
#           [2.13593750e+02, 1.32250122e+02, 8.28085938e+01],
#           [1.76558472e+02, 1.09218628e+02, 6.98903809e+01]],
#
#          [[2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.44000000e+02, 2.35000000e+02, 2.26000000e+02],
#           [2.46000000e+02, 2.37000000e+02, 2.30000000e+02],
#           ...,
#           [2.19437500e+02, 1.54514893e+02, 1.19514893e+02],
#           [2.02476562e+02, 1.31015625e+02, 8.09987793e+01],
#           [1.78923584e+02, 1.04228271e+02, 7.00086670e+01]]],
#
#
#         [[[0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01]],
#
#          [[0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01]],
#
#          [[0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 3.20000000e+01]],
#
#          ...,
#
#          [[0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01]],
#
#          [[0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01]],
#
#          [[0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           ...,
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01],
#           [0.00000000e+00, 1.00000000e+00, 2.40000000e+01]]]],
#        dtype=float32),
#  array([2, 1, 0, 1, 2, 1, 2, 2, 0, 1, 1, 1, 2, 2, 2, 1, 2, 1, 2, 2, 0, 2,
#         1, 1, 0, 1, 2, 0, 1, 2, 0, 2]))

# %%
len(batch) #images and levels
# Out:
# 2

# %%
len(batch[0]),batch[0].shape
# Out:
# (32, (32, 256, 256, 3))

# %%
len(batch[1])
# Out:
# 32

# %%
batch[1]
# Out:
# array([2, 1, 0, 1, 2, 1, 2, 2, 0, 1, 1, 1, 2, 2, 2, 1, 2, 1, 2, 2, 0, 2,
#        1, 1, 0, 1, 2, 0, 1, 2, 0, 2])

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# Preprocessing data

# %%
batch[0].min(),batch[0].max()
# Out:
# (0.0, 255.0)

# %%
data=data.map(lambda x,y:(x/255,y))

# %%
data.as_numpy_iterator().next()[0].max()
# Out:
# 1.0

# %%
data.as_numpy_iterator().next()[0].min()
# Out:
# 0.0

# %% [markdown]
# Split Data

# %%
len(data)
# Out:
# 13

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
train=data.take(train_size)
val=data.skip(train_size).take(val_size)
test=data.skip(train_size+val_size).take(test_size)

# %%
len(train)
# Out:
# 9

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

# %%
model=Sequential()

# %%
#convulation and maxpolling layer
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

#convulation and maxpolling layer
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

#convulation and maxpolling layer
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

#Flattering
model.add(Flatten())


model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
